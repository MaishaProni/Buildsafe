# %%
import streamlit as st
import pandas as pd
from models.cyclone_model import build_cvi_dataset, load_spatial_model, predict_cvi, visualize_oneplot_for_coordinate

st.title("🌪️ BuildSafe — Cyclone Vulnerability Explorer")

lat = st.number_input("Latitude", value=22.65, format="%.4f")
lon = st.number_input("Longitude", value=89.7667, format="%.4f")
show_plot = st.checkbox("Show vulnerability chart", value=True)

if st.button("Predict Vulnerability"):
    df = pd.read_csv(r"C:\Users\Maisha\OneDrive\Desktop\Buildsafe\Buildsafe\data_processing\processed_data\Updated_cyclone_data.csv")
    model, scaler = load_spatial_model("cyclone_knn.pkl")
    pred = predict_cvi(lat, lon, model, scaler)
    st.success(f"Predicted CVI: {pred:.2f} | Safety Index: {100 - pred:.2f}")
    if show_plot:
        visualize_oneplot_for_coordinate(df, lat, lon, model, scaler, k=3, show=True)
# Out:
# 2025-11-11 01:46:57.756 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.319
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Maisha\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-11 01:46:59.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.346 Session state does not function when running a script without `streamlit run`
# 2025-11-11 01:46:59.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.364 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.369 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.393 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-11 01:46:59.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
